# %%
import os
import shutil

folders_to_delete = [
    "D:\\AfterEffectsBot\\Assets\\audios",
    "D:\\AfterEffectsBot\\Assets\\captions",
    "D:\\AfterEffectsBot\\Assets\\descaled images",
    "D:\\AfterEffectsBot\\aebot_AME",
    "D:\\AfterEffectsBot\\Assets\\photos"
]

def delete_folder_contents(folder_path):
    try:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                os.remove(file_path)
                print(f"Deleted file: {file_path}")
            for dir in dirs:
                dir_path = os.path.join(root, dir)
                shutil.rmtree(dir_path)
                print(f"Deleted folder: {dir_path}")
    except Exception as e:
        print(f"Error while deleting: {e}")

for folder in folders_to_delete:
    if os.path.exists(folder):
        delete_folder_contents(folder)
    else:
        print(f"Folder not found: {folder}")

# %%
# Define the input and output file names
input_file = "list.txt"
output_file = "most_viewed_articles.txt"

with open(input_file, "r") as infile:
    lines = infile.readlines()[:4]

# Write the first 4 lines to the output file
with open(output_file, "w") as outfile:
    outfile.writelines(lines)

# Remove the first 4 lines from the input file
with open(input_file, "r") as infile:
    remaining_lines = infile.readlines()[4:]



with open(input_file, "w") as infile:
    infile.writelines(remaining_lines)

print("First 4 lines copied to", output_file)
print("First 4 lines removed from", input_file)

# %%
import openai
openai.api_key = "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"

# %% [markdown]
# FUNCTION TO START THE LIST MECHANICM

# %%
# Your code to fetch most-viewed articles and save them to a text file (as you provided previously) ...

# Initialize the current article index
current_article_index = 0

# Function to read the next article from the text file
def read_next_article():
    global current_article_index  # Use the global current_article_index
    with open("most_viewed_articles.txt", "r", encoding="utf-8") as file:
        lines = file.readlines()
        if current_article_index < len(lines):
            next_article = lines[current_article_index].strip()  # Remove leading/trailing whitespace
            current_article_index += 1
            return next_article
        else:
            return None  # No more articles

# %% [markdown]
# CHAT GPT API FUNCTION [LOOP1]

# %%
import time
import threading
import os
import re
import openai

# Initialize the OpenAI API with your API key
openai.api_key = "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"

# Define the base filename for YouTube scripts
base_filename = "youtube"

# Initialize a counter for generating unique filenames
counter = 1

def response_thread(next_article):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": "From now on, you will only reply with YouTube scripts on the topic that I provide. The YouTube scripts should include random facts, informative information, and only spoken text should be generated. Do not specify who is speaking the text, such as host or narrator. If you understand, say OK."},
            {"role": "assistant", "content": "OK."},
            {"role": "user", "content": next_article}
        ],
        max_tokens=1000  # Adjust the number of tokens as needed
    )

    response_text = response.choices[0].message.content

    # Generate a filename by appending the counter
    global counter
    while True:
        filename = f"{base_filename}{counter}.txt"
        if not os.path.exists(filename):
            break
        counter += 1

    # Define a regular expression pattern to match text within square brackets
    pattern = r'\[.*?\]'

    # Use the re.sub() function to remove text within square brackets
    
    cleaned_youtube_script = re.sub(pattern, '', response_text)

    # Write the cleaned content to the generated filename
    with open(filename, "w", encoding="utf-8") as file:
        file.write(cleaned_youtube_script)

    # Print the filename to confirm where the content has been written
    print(f"YouTube script has been written to {filename}")

while True:
    # Set a start time
    start_time = time.time()

    # Run the code once
    next_article = read_next_article()

    if next_article is not None:
        response_thread_thread = threading.Thread(target=response_thread, args=(next_article,))
        response_thread_thread.start()

        response_thread_thread.join(timeout=300)  # Wait for up to 30 seconds (adjust as needed)

        if response_thread_thread.is_alive():
            print("Response generation took more than the specified time. Restarting...")
            response_thread_thread.join()  # Wait for the thread to finish gracefully

    else:
        print("No more articles to read")
        break
# Out:
# Hey there, fishing enthusiasts! Today, we're diving deep into the world of angling, exploring fascinating facts and informative tidbits about this beloved pastime.
#
# Did you know that fishing is one of the oldest activities known to humanity? It dates back at least 40,000 years when our ancestors used simple tools made from bone and stone to catch fish in rivers and lakes. Talk about a longstanding tradition!
#
# Now, let's talk about some random facts about fishing. Did you know that the largest freshwater fish ever caught was a Mekong giant catfish? It was a whopping 10 feet long and weighed over 650 pounds! Imagine reeling that monster in!
#
# Speaking of big catches, have you ever heard about the incredible senses fish possess? Some species, like the catfish, have taste buds located on their whiskers, allowing them to taste their food even before it enters their mouths. Quite a unique adaptation, don't you think?
#
# But fishing isn't just about catching the biggest fish—it's also about conservation and sustainability. Understanding the delicate balance of aquatic ecosystems is crucial. For example, did you know that certain types of fish, like the cleaner wrasse, help other fish by picking parasites off their bodies? It's like a natural spa treatment for our aquatic friends!
#
# As we wrap up today's video, let's take a moment to appreciate the joys of fishing. It's not just about the catch; it's about the peacefulness of being out on the water, the thrill of the chase, and the connection with nature that it provides.
#
# Remember, whether you're a seasoned angler or a beginner casting your first line, fishing is a wonderful way to relax, learn, and make memories that'll last a lifetime. So, grab your gear and head out to the nearest fishing spot. Tight lines, happy fishing, and until next time, take care out there!

# %% [markdown]
# SAVE THE OUTPUT OF CHAT GPT IN TXT FILES [LOOP2]

# %%
import os
import re  # Import the 're' module for regular expressions

# Define the base filename
base_filename = "youtube"

# Initialize a counter
counter = 1

# Generate a filename by appending the counter
while True:
    filename = f"{base_filename}{counter}.txt"
    if not os.path.exists(filename):
        break
    counter += 1

# Assuming you have the response from OpenAI stored in a variable 'response'
youtube_script = response['choices'][0]['message']['content']

# Define a regular expression pattern to match text within square brackets
pattern = r'\[.*?\]'

# Use the re.sub() function to remove text within square brackets
cleaned_youtube_script = re.sub(pattern, '', youtube_script)

# Write the cleaned content to the generated filename
with open(filename, "w", encoding="utf-8") as file:
    file.write(cleaned_youtube_script)

# Print the filename to confirm where the content has been written
print(f"YouTube script has been written to {filename}.")
# Out:
# YouTube script has been written to youtube1.txt.

# %% [markdown]
# Text To Speech Function

# %%
import os

# Define the base filename
base_filename = "youtube"

# Initialize a counter
counter = 1

# Generate a filename by appending the counter
filename = f"{base_filename}{counter}.txt"

# Check if the file exists

# %% [markdown]
# RUN THIS COMMAND TO CHANGE THE "SCRIPT" FUNCTION TO THE NEXT TXT FILE [LOOP3]

# %%
if os.path.exists(filename):
    # Read the content from the generated filename
    with open(filename, "r", encoding="utf-8") as file:
        youtube_content = file.read().strip()
        
        
        print(filename +" This txt file is now set as script")

# Increment the counter for the next run
counter += 1

    # Generate the filename for the next run
filename = f"{base_filename}{counter}.txt"

# Print a message when all existing files have been processed
print("All existing YouTube script files have been processed.")
print(filename +" This Txt file will be set as script the next time")
# Out:
# youtube1.txt This txt file is now set as script
# All existing YouTube script files have been processed.
# youtube2.txt This Txt file will be set as script the next time

# %% [markdown]
# MAIN TTS FUNCTION [LOOP4]

# %%
import os
from scipy.io.wavfile import write as write_wav
from bark.api import semantic_to_waveform
from bark import generate_audio, SAMPLE_RATE
from IPython.display import Audio
import nltk
import numpy as np

nltk.download('punkt')

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

from bark.generation import (generate_text_semantic, preload_models)

preload_models()



# Define the script with the content replaced
script = f"""{youtube_content}""".replace("\n", " ").strip()

sentences = nltk.sent_tokenize(script)

SPEAKER = "v2/en_speaker_9"
silence = np.zeros(int(0.25 * SAMPLE_RATE))  # quarter second of silence

pieces = []
for sentence in sentences:
    audio_array = generate_audio(sentence, history_prompt=SPEAKER)
    pieces += [audio_array, silence.copy()]

# Concatenate audio pieces
concatenated_audio = np.concatenate(pieces)






# Define the base filename for WAV files along with the desired path
output_directory = "D:\AfterEffectsBot\Assets\\audios"
base_filename = "youtube_audio"

# Initialize a counter
counter = 1

# Generate a unique filename by appending the counter
wav_filename = os.path.join(output_directory, f"{base_filename}{counter}.wav")

# Check if the file exists
while os.path.exists(wav_filename):
    # Use a unique filename for each WAV file
    counter += 1
    wav_filename = os.path.join(output_directory, f"{base_filename}{counter}.wav")

# Use the unique filename to create the WAV file
write_wav(wav_filename, SAMPLE_RATE, concatenated_audio)

# Display the audio
Audio(concatenated_audio, rate=SAMPLE_RATE)

# Print the filename to confirm where the WAV file has been saved
print(f"WAV file has been saved as {wav_filename}.")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\singl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# C:\Users\singl\AppData\Roaming\Python\Python311\site-packages\torch\nn\utils\weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# 100%|██████████| 130/130 [00:02<00:00, 51.97it/s]
# 100%|██████████| 7/7 [00:05<00:00,  1.19it/s]
# 100%|██████████| 541/541 [00:07<00:00, 68.17it/s]
# 100%|██████████| 28/28 [00:23<00:00,  1.21it/s]
# 100%|██████████| 314/314 [00:04<00:00, 64.76it/s]
# 100%|██████████| 16/16 [00:13<00:00,  1.18it/s]
# 100%|██████████| 718/718 [00:10<00:00, 67.90it/s]
# 100%|██████████| 36/36 [00:30<00:00,  1.19it/s]
# 100%|██████████| 193/193 [00:02<00:00, 66.96it/s]
# 100%|██████████| 10/10 [00:08<00:00,  1.21it/s]
# 100%|██████████| 276/276 [00:04<00:00, 66.63it/s]
# 100%|██████████| 14/14 [00:12<00:00,  1.17it/s]
# 100%|██████████| 350/350 [00:05<00:00, 68.46it/s]
# 100%|██████████| 18/18 [00:14<00:00,  1.21it/s]
# 100%|██████████| 395/395 [00:05<00:00, 69.68it/s]
# 100%|██████████| 20/20 [00:16<00:00,  1.21it/s]
# 100%|██████████| 152/152 [00:02<00:00, 65.25it/s]
# 100%|██████████| 8/8 [00:06<00:00,  1.22it/s]
# 100%|██████████| 337/337 [00:05<00:00, 66.89it/s]
# 100%|██████████| 17/17 [00:14<00:00,  1.18it/s]
# 100%|██████████| 573/573 [00:08<00:00, 68.30it/s]
# 100%|██████████| 29/29 [00:24<00:00,  1.19it/s]
# 100%|██████████| 549/549 [00:07<00:00, 70.74it/s]
# 100%|██████████| 28/28 [00:23<00:00,  1.17it/s]
# 100%|██████████| 459/459 [00:07<00:00, 63.76it/s]
# 100%|██████████| 23/23 [00:19<00:00,  1.18it/s]
# 100%|██████████| 286/286 [00:04<00:00, 65.51it/s]
# 100%|██████████| 15/15 [00:12<00:00,  1.22it/s]
# 100%|██████████| 525/525 [00:07<00:00, 70.06it/s]
# 100%|██████████| 27/27 [00:22<00:00,  1.18it/s]
# 100%|██████████| 249/249 [00:03<00:00, 65.73it/s]
# 100%|██████████| 13/13 [00:10<00:00,  1.22it/s]
# 100%|██████████| 351/351 [00:05<00:00, 69.10it/s]
# 100%|██████████| 18/18 [00:14<00:00,  1.25it/s]
# 100%|██████████| 682/682 [00:09<00:00, 73.03it/s]
# 100%|██████████| 35/35 [00:27<00:00,  1.28it/s]
# 100%|██████████| 715/715 [00:10<00:00, 70.20it/s]
# 100%|██████████| 36/36 [00:29<00:00,  1.23it/s]
# 100%|██████████| 405/405 [00:05<00:00, 72.38it/s]
# 100%|██████████| 21/21 [00:17<00:00,  1.22it/s]
# 100%|██████████| 705/705 [00:10<00:00, 67.83it/s]
# 100%|██████████| 36/36 [00:30<00:00,  1.19it/s]
# WAV file has been saved as D:\AfterEffectsBot\Assets\audios\youtube_audio1.wav.

# %%
import time

# Define the number of iterations for the loop
num_iterations = 3

# Loop to execute the scripts multiple times
for iteration in range(num_iterations):
    print(f"Iteration {iteration + 1}:")

    # --- Insert your first Python script here ---
    # This is where you place the code from your first script
    # For example, you can put:
    exec(open("D:\Youtube Bot Audio\Scripts\loop1chatgpt.py").read())

    # Wait for the first script to finish before moving to the next one
    
    # This is where you place the code from your second script
    # For example, you can put:
    exec(open("D:\Youtube Bot Audio\Scripts\loop2savingchatgpt.py").read())

    # Wait for the second script to finish before moving to the next one
    

    # --- Insert your third Python script here ---
    # This is where you place the code from your third script
    # For example, you can put:
    # Wait for the third script to finish before moving to the next one
    

    # --- Insert your fourth Python script here ---
    # This is where you place the code from your fourth script
    # For example, you can put:
    exec(open("D:\Youtube Bot Audio\Scripts\loop3changescript.py").read())

    # After executing all scripts in this iteration, you can make additional changes if needed
    # For example:
    # final_variable_to_modify = "Final Value"

    exec(open("D:\Youtube Bot Audio\Scripts\loop4tts.py").read())

    # Add a delay (optional) to control the timing between iterations
    if iteration < num_iterations - 1:
        time.sleep(2)  # Sleep for 2 seconds before the next iteration

# End of the loop
print("Loop completed.")
# Out:
# Iteration 1:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\singl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#

# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\singl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Hey there, sports fans! Today, we're diving into the exhilarating world of cricket and taking a closer look at none other than the Cricket World Cup. Get ready for a blitz of random facts and informative tidbits that'll leave you batting for more!
#
# Did you know that the Cricket World Cup is an international tournament held every four years, showcasing the best cricket teams from around the globe? It all began back in 1975 when the inaugural edition took place in England. Since then, cricket enthusiasts have eagerly awaited this quadrennial event with bated breath.
#
# Speaking of breath, did you know that cricket as a sport can be traced back over 500 years? It originated in England and has since spread its wings to become a global phenomenon, loved by millions of fans today. Quite a rich history, wouldn't you agree?
#
# But let's focus on the Cricket World Cup itself. Over the years, a whopping eleven different nations have had the honor of hosting this prestigious tournament. From England to India, Australia to Sri Lanka, and many more, each host country brings its unique flavor to the tournament, making it a truly global spectacle.
#
# Now, here's a random fact for you: The highest individual score in a Cricket World Cup match was achieved by the legendary Chris Gayle from the West Indies. In the 2015 edition, he smashed an astonishing 215 runs in a single innings against Zimbabwe, leaving the opposition bowlers shell-shocked!
#
# In case you're wondering about team performances in the Cricket World Cup, it's worth mentioning that Australia has been the most successful team in the history of the tournament. The powerhouse nation has clinched the title a record-breaking five times. Talk about dominance on the cricket field!
#
# But wait, there's more. Did you know that the iconic trophy presented to the winners of the Cricket World Cup is called the ICC Cricket World Cup Trophy? It stands tall at 60 centimeters and weighs a solid 11 kilograms, making it quite the prestigious prize for any cricket team to lift.
#
# And here's another interesting tidbit! The ongoing rivalry between India and Pakistan often takes center stage in the Cricket World Cup. Matches between these two cricketing powerhouses always generate immense excitement and capture the attention of fans worldwide. A true clash of the titans!
#
# Well, there you have it, folks! Our whirlwind tour through the Cricket World Cup, complete with random facts and informative information. We hope you enjoyed this deep dive into the thrilling world of cricket. Until next time, keep those wickets spinning and those boundaries soaring. Cheers!
# YouTube script has been written to youtube3.txt.
# youtube3.txt This txt file is now set as script
# All existing YouTube script files have been processed.
# youtube4.txt This Txt file will be set as script the next time
# 100%|██████████| 173/173 [00:02<00:00, 65.14it/s]
# 100%|██████████| 9/9 [00:07<00:00,  1.23it/s]
# 100%|██████████| 557/557 [00:08<00:00, 66.79it/s]
# 100%|██████████| 28/28 [00:23<00:00,  1.19it/s]
# 100%|██████████| 519/519 [00:07<00:00, 71.81it/s]
# 100%|██████████| 26/26 [00:21<00:00,  1.20it/s]
# 100%|██████████| 633/633 [00:09<00:00, 66.78it/s]
# 100%|██████████| 32/32 [00:26<00:00,  1.22it/s]
# 100%|██████████| 365/365 [00:05<00:00, 72.17it/s]
# 100%|██████████| 19/19 [00:15<00:00,  1.20it/s]
# 100%|██████████| 522/522 [00:07<00:00, 67.56it/s]

# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\singl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [Background music plays]
#
# [Scenic shots of the Gaza Strip]
#
# Narrator: Welcome to today's video, where we'll be exploring fascinating facts about the Gaza Strip. Located on the southeastern coast of the Mediterranean Sea, the Gaza Strip is a relatively small territory with a rich history and diverse culture.
#
# [Animated map of the Gaza Strip appears]
#
# Fact 1: The Gaza Strip is approximately 365 square kilometers in size, making it one of the most densely populated areas on Earth. It is home to over 2 million people.
#
# [Population graphics appear]
#
# Fact 2: The city of Gaza, the largest in the territory, has an ancient history that dates back more than 4,000 years. It has witnessed the rise and fall of numerous civilizations, including ancient Egypt, Persians, Romans, and Byzantines, to name a few.
#
# [Visuals of ancient ruins and artifacts]
#
# Fact 3: The economy of the Gaza Strip heavily relies on agriculture, fishing, and industry, despite facing numerous challenges due to its political situation. Olive production, citrus fruits, and vegetable farming are significant contributors to the local economy.
#
# [Agricultural footage]
#
# Fact 4: The Gaza Strip is known for its vibrant cultural heritage. Its traditional folk dances, such as the "Dabke," are a source of pride for the locals. The region is also famous for its traditional handicrafts, like embroidery and ceramics.
#
# [Clip of Dabke dancing and local crafts]
#
# Fact 5: Unfortunately, the Gaza Strip has been plagued by conflict and political instability for many years. Its geographical location and political circumstances have made it a focal point of tensions and disputes between different parties involved.
#
# [Images of political protests and conflicts]
#
# Fact 6: Despite the challenges, the resilience and determination of the people in the Gaza Strip are remarkable. They have adapted to their circumstances and found innovative ways to overcome obstacles, such as through entrepreneurship and education.
#
# [Positive footage of community initiatives]
#
# Fact 7: The Gaza Strip is renowned for its picturesque coastline along the Mediterranean Sea. Its sandy beaches and clear blue waters attract visitors from around the world, providing a much-needed escape and source of joy for the local residents.
#
# [Scenic shots of Gaza's coastline]
#
# Closing statement: The Gaza Strip is a place of both beauty and hardship. Its history, culture, and enduring spirit continue to shape the lives of its people. We must strive for peace and understanding in this complex region, respecting the experiences and aspirations of its residents.
#
# [Closing music plays]
#
# Narrator: That wraps up our exploration of the Gaza Strip. We hope you've learned something new today. If you enjoyed this video, remember to give it a thumbs up and subscribe to our channel for more informative content. Until next time, take care and keep exploring the world!
#
# [End screen and subscribe button appear]
# YouTube script has been written to youtube4.txt.
# youtube4.txt This txt file is now set as script
# All existing YouTube script files have been processed.
# youtube5.txt This Txt file will be set as script the next time
# 100%|██████████| 344/344 [00:05<00:00, 68.50it/s]
# 100%|██████████| 18/18 [00:14<00:00,  1.23it/s]
# 100%|██████████| 613/613 [00:08<00:00, 71.25it/s]
# 100%|██████████| 31/31 [00:25<00:00,  1.24it/s]
# 100%|██████████| 563/563 [00:08<00:00, 66.59it/s]
# 100%|██████████| 29/29 [00:23<00:00,  1.23it/s]
# 100%|██████████| 180/180 [00:02<00:00, 71.23it/s]
# 100%|██████████| 9/9 [00:08<00:00,  1.12it/s]
# 100%|██████████| 526/526 [00:07<00:00, 70.49it/s]
# 100%|██████████| 27/27 [00:22<00:00,  1.19it/s]
# 100%|██████████| 678/678 [00:09<00:00, 68.11it/s]
