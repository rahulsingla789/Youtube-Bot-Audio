# %%
import openai
openai.api_key = "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"

# %%
# Your code to fetch most-viewed articles and save them to a text file (as you provided previously) ...

# Initialize the current article index
current_article_index = 0

# Function to read the next article from the text file
def read_next_article():
    global current_article_index  # Use the global current_article_index
    with open("most_viewed_articles.txt", "r", encoding="utf-8") as file:
        lines = file.readlines()
        if current_article_index < len(lines):
            next_article = lines[current_article_index].strip()  # Remove leading/trailing whitespace
            current_article_index += 1
            return next_article
        else:
            return None  # No more articles

# %%
import os

# Set the counter for generated titles
counter = 1

def write_output_to_file(output):
    global counter
    filename = f"title{counter}.txt"
    with open(filename, "w") as output_file:
        output_file.write(output)
    counter += 1

# Read the next article title
next_article = read_next_article()

while next_article is not None:
    # Use the retrieved article title as input to OpenAI GPT-3.5 Turbo
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": "From now on, you will only reply with YouTube video titles on the topic that I provide. The YouTube scripts of that title includes random facts, informative information. If you understand, say OK."},
            {"role": "assistant", "content": "OK."},
            {"role": "user", "content":"You will only and only write the title in output nothing else"},
            {"role": "assistant", "content": "OK, I will only Respond With a single Youtube Video Title in the output nothing else"},
            #{"role": "user", "content":"You Will not include any text that will not be actually spoken in the actual YouTube script, for example title, [Upbeat music playing] etc, just write the text that will actually be spoken. If you understand, say OK"},
            #{"role": "assistant", "content": "OK."},  
            {"role": "user", "content": next_article}
        ],
        max_tokens=100  # Adjust the number of tokens as needed
    )

    # Get the response generated by GPT-3.5 Turbo
    generated_output = response.choices[0].message.content

    # Print and write the output to a file
    print(generated_output)
    write_output_to_file(generated_output)

    # Read the next article title for the next iteration
    next_article = read_next_article()

print("No more articles to read.")
# Out:
# "7 Proven Fishing Techniques That Will Up Your Game"
# Amazing Facts About Crocodiles
# "Top 10 Moments of the Cricket World Cup"
# "Inside the Gaza Strip: Life Under Occupation"
# Inside the World of Tesla - The Most Innovative Electric Car Company
# Hamas: Explained in 5 Minutes
# "The Israel-Hamas Conflict Explained: Causes, Timeline, and Impacts"
# "The Rise and Dominance of India National Cricket Team - A Journey to Glory"
# "10 Amazing Facts About Israel You Didn't Know!"
# The History of Palestine Explained in 10 Minutes
# No more articles to read.

# %%
import openai
openai.api_key = "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"

# %%
# Your code to fetch most-viewed articles and save them to a text file (as you provided previously) ...

# Initialize the current article index
current_article_index = 0

# Function to read the next article from the text file
def read_next_article():
    global current_article_index  # Use the global current_article_index
    with open("most_viewed_articles.txt", "r", encoding="utf-8") as file:
        lines = file.readlines()
        if current_article_index < len(lines):
            next_article = lines[current_article_index].strip()  # Remove leading/trailing whitespace
            current_article_index += 1
            return next_article
        else:
            return None  # No more articles

# %%
import os

# Set the counter for generated titles
counter = 1

def write_output_to_file(output):
    global counter
    filename = f"description{counter}.txt"
    with open(filename, "w") as output_file:
        output_file.write(output)
    counter += 1

# Read the next article title
next_article = read_next_article()

while next_article is not None:
    # Use the retrieved article title as input to OpenAI GPT-3.5 Turbo
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": "From now on, you will only reply with YouTube video Description on the topic that I provide. The YouTube scripts of that title includes random facts, informative information. If you understand, say OK."},
            {"role": "assistant", "content": "OK."},
            {"role": "user", "content":"You will only and only write the Description in output nothing else"},
            {"role": "assistant", "content": "OK, I will only Respond With a single relevent Youtube Video Description in the output nothing else"},
            #{"role": "user", "content":"You Will not include any text that will not be actually spoken in the actual YouTube script, for example title, [Upbeat music playing] etc, just write the text that will actually be spoken. If you understand, say OK"},
            #{"role": "assistant", "content": "OK."},  
            {"role": "user", "content": next_article}
        ],
        max_tokens=1000  # Adjust the number of tokens as needed
    )

    # Get the response generated by GPT-3.5 Turbo
    generated_output = response.choices[0].message.content

    # Print and write the output to a file
    print(generated_output)
    write_output_to_file(generated_output)

    # Read the next article title for the next iteration
    next_article = read_next_article()

print("No more articles to read.")
# Out:
# Join us on a thrilling fishing adventure as we explore the world of angling! In this informative video, we dive into the art of fishing and share valuable tips and techniques for beginners and seasoned anglers alike. Discover the best fishing spots, learn about different fish species, and uncover the secrets to selecting the perfect bait and tackle. Get ready to reel in some big catches and make unforgettable memories on your next fishing expedition. Don't miss out on this must-watch video for all fishing enthusiasts!
# ...

# %%
import openai
openai.api_key = "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"

# %%
# Your code to fetch most-viewed articles and save them to a text file (as you provided previously) ...

# Initialize the current article index
current_article_index = 0

# Function to read the next article from the text file
def read_next_article():
    global current_article_index  # Use the global current_article_index
    with open("most_viewed_articles.txt", "r", encoding="utf-8") as file:
        lines = file.readlines()
        if current_article_index < len(lines):
            next_article = lines[current_article_index].strip()  # Remove leading/trailing whitespace
            current_article_index += 1
            return next_article
        else:
            return None  # No more articles

# %%
import os

# Set the counter for generated titles
counter = 1

def write_output_to_file(output):
    global counter
    filename = f"keywords{counter}.txt"
    with open(filename, "w") as output_file:
        output_file.write(output)
    counter += 1

# Read the next article title
next_article = read_next_article()

while next_article is not None:
    # Use the retrieved article title as input to OpenAI GPT-3.5 Turbo
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": "From now on, you will only reply with YouTube video keywords on the topic that I provide. The YouTube scripts of that title includes random facts, informative information. If you understand, say OK."},
            {"role": "assistant", "content": "OK."},
            {"role": "user", "content":"You will only and only write the Keywords in output nothing else"},
            {"role": "assistant", "content": "OK, I will only Respond With a some relevent Youtube Video Keywords in the output nothing else"},
            {"role": "user", "content":"The Format of the keyowrds will be , keyword1, keyword2, keyword3, keyword4 and so on. no other format should be used. If You understand say ok."},
            {"role": "assistant", "content": "OK, now i will only use   keyword1, keyword2, keyword3, keyword4 this format to provide keywords. i shall use no other format"},  
            {"role": "user", "content": next_article}
        ],
        max_tokens=1000  # Adjust the number of tokens as needed
    )

    # Get the response generated by GPT-3.5 Turbo
    generated_output = response.choices[0].message.content

    # Print and write the output to a file
    print(generated_output)
    write_output_to_file(generated_output)

    # Read the next article title for the next iteration
    next_article = read_next_article()

print("No more articles to read.")
# Out:
# fishing, angling, fish species, fishing techniques, fishing tackle
# keyword1: Crocodile facts
# keyword2: Largest crocodile species
# keyword3: Crocodile behavior
# keyword4: Crocodile habitat
# keyword5: Crocodile feeding habits
# keyword6: Crocodile reproduction
# keyword7: Crocodile adaptations
# keyword8: Crocodile attacks
# keyword9: Crocodile conservation
# keyword10: Crocodile myths and legends
# cricket world cup, cricket history, cricket records, cricket teams, cricket legends, cricket facts
# Gaza Strip, Palestinian, Middle East, Conflict, Hamas, Israel, Blockade, Refugee Camps, Gaza City, Palestine, United Nations, Human Rights, History, Siege, Occupation, Border, Palestinian Authority, Economy, Gaza War, Security, Palestinian-Israeli Conflict
# Tesla, electric cars, sustainable transportation, Elon Musk, autonomous driving
# Hamas, Palestinian conflict, Israeli-Palestinian conflict, Gaza Strip, militant group, political organization
# ...

# %%
import os

# Directory containing the .mp4 files
directory_path = "D:\AfterEffectsBot\output"

# List all .mp4 files in the directory and sort them numerically
mp4_files = [f for f in os.listdir(directory_path) if f.endswith(".mp4")]
mp4_files.sort(key=lambda x: int(''.join(filter(str.isdigit, x))))

# Create text files with the paths
for i, mp4_file in enumerate(mp4_files, start=1):
    file_path = os.path.join(directory_path, mp4_file)
    output_file = f"filepath{i}.txt"

    with open(output_file, "w") as file:
        file.write(file_path)
        print(f"Created {output_file} with path: {file_path}")
# Out:
# Created filepath1.txt with path: D:\AfterEffectsBot\output\youtube_video1.mp4
# Created filepath2.txt with path: D:\AfterEffectsBot\output\youtube_video2.mp4
# Created filepath3.txt with path: D:\AfterEffectsBot\output\youtube_video3.mp4
# Created filepath4.txt with path: D:\AfterEffectsBot\output\youtube_video4.mp4
# Created filepath5.txt with path: D:\AfterEffectsBot\output\youtube_video5.mp4
# Created filepath6.txt with path: D:\AfterEffectsBot\output\youtube_video6.mp4
# Created filepath7.txt with path: D:\AfterEffectsBot\output\youtube_video7.mp4
# Created filepath8.txt with path: D:\AfterEffectsBot\output\youtube_video8.mp4
# Created filepath9.txt with path: D:\AfterEffectsBot\output\youtube_video9.mp4
# Created filepath10.txt with path: D:\AfterEffectsBot\output\youtube_video10.mp4
# Created filepath11.txt with path: D:\AfterEffectsBot\output\youtube_video11.mp4
# Created filepath12.txt with path: D:\AfterEffectsBot\output\youtube_video12.mp4

# %%
import os

# List of prefixes for the files you want to edit
prefixes_to_edit = ["title", "keywords", "description", "filepath"]

# Directory where the files are located
directory_path = "D:\Youtube Bot Audio"  # Replace with the actual directory path

# Function to remove double quotes from a file
def remove_double_quotes_from_file(file_path):
    with open(file_path, 'r') as file:
        file_content = file.read()
    
    # Remove double quotes from the content
    updated_content = file_content.replace('"', '')

    with open(file_path, 'w') as file:
        file.write(updated_content)

# Iterate through the directory and edit files with the specified prefixes
for prefix in prefixes_to_edit:
    for filename in os.listdir(directory_path):
        if filename.startswith(prefix) and filename.endswith(".txt"):
            file_path = os.path.join(directory_path, filename)
            remove_double_quotes_from_file(file_path)
            print(f"Edited: {file_path}")
# Out:
# Edited: D:\Youtube Bot Audio\title1.txt
# Edited: D:\Youtube Bot Audio\title10.txt
# Edited: D:\Youtube Bot Audio\title2.txt
# Edited: D:\Youtube Bot Audio\title3.txt
# Edited: D:\Youtube Bot Audio\title4.txt
# Edited: D:\Youtube Bot Audio\title5.txt
# Edited: D:\Youtube Bot Audio\title6.txt
# Edited: D:\Youtube Bot Audio\title7.txt
# Edited: D:\Youtube Bot Audio\title8.txt
# Edited: D:\Youtube Bot Audio\title9.txt
# Edited: D:\Youtube Bot Audio\keywords1.txt
# Edited: D:\Youtube Bot Audio\keywords10.txt
# Edited: D:\Youtube Bot Audio\keywords2.txt
# Edited: D:\Youtube Bot Audio\keywords3.txt
# Edited: D:\Youtube Bot Audio\keywords4.txt
# Edited: D:\Youtube Bot Audio\keywords5.txt
# Edited: D:\Youtube Bot Audio\keywords6.txt
# Edited: D:\Youtube Bot Audio\keywords7.txt
# Edited: D:\Youtube Bot Audio\keywords8.txt
# Edited: D:\Youtube Bot Audio\keywords9.txt
# Edited: D:\Youtube Bot Audio\description1.txt
# Edited: D:\Youtube Bot Audio\description10.txt
# ...

# %%
import os

# Initialize a counter to keep track of input files
input_file_counter = 1

# Continue processing while there are input files
while True:
    # Define the input file names
    title_file_name = f"title{input_file_counter}.txt"
    filepath_file_name = f"filepath{input_file_counter}.txt"
    description_file_name = f"description{input_file_counter}.txt"
    keywords_file_name = f"keywords{input_file_counter}.txt"

    # Check if the input files exist
    if os.path.exists(title_file_name) and os.path.exists(filepath_file_name) and os.path.exists(description_file_name) and os.path.exists(keywords_file_name):
        # Read the content from input files
        with open(title_file_name, "r") as title_file:
            title = title_file.read().strip()

        with open(filepath_file_name, "r") as file_file:
            file_path = file_file.read().strip()

        with open(description_file_name, "r") as description_file:
            description = description_file.read().strip()

        with open(keywords_file_name, "r") as keywords_file:
            keywords = keywords_file.read().strip()

        # Generate the final command line
        command_line = f'python upload_video.py --file="{file_path}" --title="{title}" --description="{description}" --keywords="{keywords}" --category="22" --privacyStatus="private"'

        # Write the command line to the corresponding output file
        with open(f"final_command{input_file_counter}.txt", "w") as output_file:
            output_file.write(command_line)

        # Increment the input file counter
        input_file_counter += 1
    else:
        # No more input files found, exit the loop
        break

# %%
import subprocess
import os

# Set the folder path where authentication tokens are located
auth_token_folder = 'D:\Youtube Bot Audio\Youtube Upload Files'

# Initialize a counter for final_command files
counter = 1

while True:
    # Construct the filename for the next final_command file
    final_command_file = f'final_command{counter}.txt'

    # Check if the file exists
    if not os.path.exists(final_command_file):
        break  # No more final_command files found, exit the loop

    # Determine the number of authentication token files dynamically
    auth_token_files = [f for f in os.listdir(auth_token_folder) if f.startswith('authenticationtoken')]
    max_auth_token_counter = len(auth_token_files)

    # Initialize the auth_token_counter
    auth_token_counter = 1

    authentication_tokens_exist = False  # Flag to check if authentication tokens exist

    while auth_token_counter <= max_auth_token_counter:
        # Build the authentication token filename
        auth_token_filename = os.path.join(auth_token_folder, f'authenticationtoken{auth_token_counter}.json')

        if os.path.exists(auth_token_filename):
            authentication_tokens_exist = True  # Set the flag to True
            # Print a message when replacing with an authentication token
            print(f"Replacing upload_video.py-oauth2.json with {auth_token_filename}")
            print(f"Using final command: {final_command_file}")  # Print the current final command

            # Read and copy content of the selected authentication token file
            with open(auth_token_filename, 'r') as auth_token_file:
                auth_token_data = auth_token_file.read()
            # Replace the content of upload_video.py-oauth2.json
            with open('upload_video.py-oauth2.json', 'w') as oauth2_file:
                oauth2_file.write(auth_token_data)

            # Read the command from the current final_command file
            with open(final_command_file, 'r') as file:
                cmd = file.read()

            # Execute the command and capture both stdout and stderr
            result = subprocess.run(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

            # Print the output of the command
            print(result.stdout)

            # Check the return code
            if result.returncode == 0:
                # Command executed successfully
                if "Video id" in result.stdout:
                    # Video was successfully uploaded
                    # Your code for handling a successful upload goes here
                    break  # Exit the loop for this final_command file

        # Increment the authentication token counter for the next iteration
        auth_token_counter += 1

    # Increment the final_command counter for the next file
    counter += 1

# The code provided loops through final_command files and tries different authentication tokens, up to the maximum number of files in the folder.
# Out:
# Replacing upload_video.py-oauth2.json with D:\Youtube Bot Audio\Youtube Upload Files\authenticationtoken1.json
# Using final command: final_command1.txt
# Uploading file...
# An HTTP error 403 occurred:
# b'{\n  "error": {\n    "code": 403,\n    "message": "The request cannot be completed because you have exceeded your \\u003ca href=\\"/youtube/v3/getting-started#quota\\"\\u003equota\\u003c/a\\u003e.",\n    "errors": [\n      {\n        "message": "The request cannot be completed because you have exceeded your \\u003ca href=\\"/youtube/v3/getting-started#quota\\"\\u003equota\\u003c/a\\u003e.",\n        "domain": "youtube.quota",\n        "reason": "quotaExceeded"\n      }\n    ]\n  }\n}\n'
#
# Replacing upload_video.py-oauth2.json with D:\Youtube Bot Audio\Youtube Upload Files\authenticationtoken2.json
# Using final command: final_command1.txt
# Uploading file...
# An HTTP error 403 occurred:
# ...

# %%
import os

# List of prefixes for the files you want to delete
prefixes_to_delete = ["title", "keywords", "description", "filepath", "final_command"]

# Directory where the files are located
directory_path = "D:\Youtube Bot Audio"  # Replace with the actual directory path

# Iterate through the directory and delete files with the specified prefixes
for prefix in prefixes_to_delete:
    for filename in os.listdir(directory_path):
        if filename.startswith(prefix) and filename.endswith(".txt"):
            file_path = os.path.join(directory_path, filename)
            os.remove(file_path)
            print(f"Deleted: {file_path}")
# Out:
# Deleted: D:\Youtube Bot Audio\title1.txt
# Deleted: D:\Youtube Bot Audio\title10.txt
# Deleted: D:\Youtube Bot Audio\title2.txt
# Deleted: D:\Youtube Bot Audio\title3.txt
# Deleted: D:\Youtube Bot Audio\title4.txt
# Deleted: D:\Youtube Bot Audio\title5.txt
# Deleted: D:\Youtube Bot Audio\title6.txt
# Deleted: D:\Youtube Bot Audio\title7.txt
# Deleted: D:\Youtube Bot Audio\title8.txt
# Deleted: D:\Youtube Bot Audio\title9.txt
# Deleted: D:\Youtube Bot Audio\keywords1.txt
# Deleted: D:\Youtube Bot Audio\keywords10.txt
# Deleted: D:\Youtube Bot Audio\keywords2.txt
# Deleted: D:\Youtube Bot Audio\keywords3.txt
# Deleted: D:\Youtube Bot Audio\keywords4.txt
# Deleted: D:\Youtube Bot Audio\keywords5.txt
# Deleted: D:\Youtube Bot Audio\keywords6.txt
# Deleted: D:\Youtube Bot Audio\keywords7.txt
# Deleted: D:\Youtube Bot Audio\keywords8.txt
# Deleted: D:\Youtube Bot Audio\keywords9.txt
# Deleted: D:\Youtube Bot Audio\description1.txt
# Deleted: D:\Youtube Bot Audio\description10.txt
# ...
